# %% [markdown]
# In this analysis I just wanted to see how the projection of $P_{\alpha}$ looks like.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.io import FortranFile as ff

# %%
ras = '/home/shikhar/work/Semelin/s07_e6_Nscat.dat'
f = ff(ras)
[lev] = f.read_ints()
raw = f.read_reals('d')
np.nan_to_num(raw,copy=False)

palpha=np.reshape(raw,[2**lev,2**lev,2**lev],order='F')
print(np.min(palpha[palpha>0]))
#palpha=palpha/np.min(palpha[palpha>0]) #normalising palpha
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

fig,ax=plt.subplots(figsize=(8.3,7.5),dpi=150)
c=ax.imshow(palpha[:,:,128].T,cmap='brg',aspect='equal',origin='lower',norm=colors.LogNorm())
#divider = make_axes_locatable(ax)
#cax = divider.append_axes("right", size="5%", pad=0.05)
#cb=plt.colorbar(c,cax=cax)
#cb.set_label(r'Normalised $P_{\alpha}$',fontsize=20)
#ax.set_xlabel("$x\,$(cMpc$h^{-1}$)",fontsize=20)
#ax.set_ylabel("$y\,$(cMpc$h^{-1}$)",fontsize=20)
ax.tick_params(axis='both', which='major', length=5, width=1,labelsize=20,direction='in')
ax.tick_params(axis='both', which='minor', length=3, width=1,direction='in')
ax.minorticks_on()
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.set_aspect(1.0/ax.get_data_ratio(), adjustable='box')
#plt.savefig('p1e6.pdf')

# %%
ras = '/home/shikhar/work/Semelin/pa_p1e7_broad_a3.dat'
f = ff(ras)
[lev] = f.read_ints()
raw = f.read_reals('d')
np.nan_to_num(raw,copy=False)

palpha=np.reshape(raw,[2**lev,2**lev,2**lev],order='F')
print(np.min(palpha[palpha>0]))
#palpha=palpha/np.min(palpha[palpha>0]) #normalising palpha


plt.rc('text', usetex=True)
plt.rc('font', family='serif')

fig,ax=plt.subplots(figsize=(8.3,7.5),dpi=200)
fig.subplots_adjust(left=0.12, bottom=0.07, right=0.88, top=0.97)
c=ax.imshow(palpha[:,:,128].T,cmap='brg',aspect='equal',origin='lower',norm=colors.LogNorm())
#divider = make_axes_locatable(ax)
#cax = divider.append_axes("right", size="5%", pad=0.05)
#cb=plt.colorbar(c,cax=cax)
#cb.set_label(r'Normalised $P_{\alpha}$',fontsize=20)
#ax.set_xlabel("$x\,$(cMpc$h^{-1}$)",fontsize=20)
#ax.set_ylabel("$y\,$(cMpc$h^{-1}$)",fontsize=20)
ax.tick_params(axis='both', which='major', length=5, width=1,labelsize=20,direction='in')
ax.tick_params(axis='both', which='minor', length=3, width=1,direction='in')
ax.minorticks_on()
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.set_aspect(1.0/ax.get_data_ratio(), adjustable='box')
plt.savefig('p1e7.pdf')
# Out:
# 2.6887814422421444e-83

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.io import FortranFile as ff

ras = '/home/shikhar/work/Semelin/pa_p1e6_mono_lybeta.dat'
f = ff(ras)
[lev] = f.read_ints()
raw = f.read_reals('d')
np.nan_to_num(raw,copy=False)

palpha=np.reshape(raw,[2**lev,2**lev,2**lev],order='F')
print(np.min(palpha[palpha>0]))
palpha=palpha/np.min(palpha[palpha>0]) #normalising palpha


plt.rc('text', usetex=True)
plt.rc('font', family='serif')

fig,ax=plt.subplots(figsize=(8.3,7.5),dpi=150)
c=ax.imshow(palpha[:,:,128].T,cmap='brg',aspect='equal',origin='lower',norm=colors.LogNorm())
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
cb=plt.colorbar(c,cax=cax)
cb.set_label(r'Normalised $P_{\alpha}$',fontsize=20)
#ax.set_xlabel("$x\,$(cMpc$h^{-1}$)",fontsize=20)
#ax.set_ylabel("$y\,$(cMpc$h^{-1}$)",fontsize=20)
ax.tick_params(axis='both', which='major', length=5, width=1,labelsize=20,direction='in')
ax.tick_params(axis='both', which='minor', length=3, width=1,direction='in')
ax.minorticks_on()
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.set_aspect(1.0/ax.get_data_ratio(), adjustable='box')
#plt.savefig('p1e7.pdf')
# Out:
# 3.9886332450047516e-11
